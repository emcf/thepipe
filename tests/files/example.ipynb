# %% [markdown]
# Test image in markdown:
#
# ![ThePipe](https://rpnutzemutbrumczwvue.supabase.co/storage/v1/object/public/assets/pipeline_resized.png)

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()
